# %%
# %load_ext autoreload
# %autoreload 2

import sys
sys.path.append('..')

import pandas as pd
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn import set_config
import sqlite3

from src.transformers import(
    cargar_y_limpiar_pitchfork
)

print('Librerías locales importadas correctamente.')
# Out:
# Librerías locales importadas correctamente.

# %%
conn = sqlite3.connect("database.sqlite")
df_raw = pd.read_sql("SELECT * FROM reviews", conn)

variables_numericas = ['reviewid','score','best_new_music','pub_date','pub_weekday','pub_day','pub_month','pub_year']
variables_categoricas = ['title','artist','url','author','author_type']

num_pipe=Pipeline([
    ('cargar_y_limpiar_pitchfork',cargar_y_limpiar_pitchfork())
])
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# c:\Users\SSDD\anaconda3\lib\site-packages\pandas\io\sql.py in execute(self, *args, **kwargs)
#    1680         try:
# -> 1681             cur.execute(*args, **kwargs)
#    1682             return cur
#
# OperationalError: no such table: reviews
#
# The above exception was the direct cause of the following exception:
#
# DatabaseError                             Traceback (most recent call last)
# <ipython-input-4-ec314c0629ef> in <module>
#       1 conn = sqlite3.connect("database.sqlite")
# ----> 2 df_raw = pd.read_sql("SELECT * FROM reviews", conn)
#       3
#       4 variables_numericas = ['reviewid','score','best_new_music','pub_date','pub_weekday','pub_day','pub_month','pub_year']
#       5 variables_categoricas = ['title','artist','url','author','author_type']
#
# ...

# %%
pd.read_sql("SELECT * FROM sqlite_master", conn)
# Out:
# Empty DataFrame
# Columns: [type, name, tbl_name, rootpage, sql]
# Index: []
