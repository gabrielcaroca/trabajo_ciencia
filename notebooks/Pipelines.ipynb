# %%
# %load_ext autoreload
# %autoreload 2

import sys
sys.path.append('..')

import pandas as pd
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn import set_config
import sqlite3

from sklearn.base import BaseEstimator, TransformerMixin

class PitchforkLoader(BaseEstimator, TransformerMixin):
    def __init__(self, db_path):
        self.db_path = db_path

    def fit(self, X=None, y=None):
        return self

    def transform(self, X=None):
        return cargar_y_limpiar_pitchfork(self.db_path)

pipeline = Pipeline([
    ("pitchfork_loader", PitchforkLoader("data/raw/database.sqlite"))
])
print('Librerías locales importadas correctamente.')
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# Librerías locales importadas correctamente.

# %%
set_config(display="diagram")
pipeline
# Out:
# Pipeline(steps=[('pitchfork_loader',
#                  PitchforkLoader(db_path='data/raw/database.sqlite'))])
